# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
from sklearn.metrics import roc_curve, auc
df = pd.read_csv('bank-additional-full.csv', sep=';') # https://www.kaggle.com/datasets/sahistapatel96/bankadditionalfullcsv
pd.options.display.max_columns = None

df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# 0      telephone   may         mon       261         1    999         0
# 1      telephone   may         mon       149         1    999         0
# 2      telephone   may         mon       226         1    999         0
# 3      telephone   may         mon       151         1    999         0
# 4      telephone   may         mon       307         1    999         0
# ...          ...   ...         ...       ...       ...    ...       ...
# 41183   cellular   nov         fri       334         1    999         0
# 41184   cellular   nov         fri       383         1    999         0
# 41185   cellular   nov         fri       189         2    999         0
# 41186   cellular   nov         fri       442         1    999         0
# 41187   cellular   nov         fri       239         3    999         1
#
#           poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent           1.1          93.994          -36.4      4.857
# 1      nonexistent           1.1          93.994          -36.4      4.857
# 2      nonexistent           1.1          93.994          -36.4      4.857
# 3      nonexistent           1.1          93.994          -36.4      4.857
# 4      nonexistent           1.1          93.994          -36.4      4.857
# ...            ...           ...             ...            ...        ...
# 41183  nonexistent          -1.1          94.767          -50.8      1.028
# 41184  nonexistent          -1.1          94.767          -50.8      1.028
# 41185  nonexistent          -1.1          94.767          -50.8      1.028
# 41186  nonexistent          -1.1          94.767          -50.8      1.028
# 41187      failure          -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [41188 rows x 21 columns]

# %% [markdown]
# Аналитика

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
sns.set(style="whitegrid")
plt.figure(figsize=(12, 6))

print("═"*50)
print("1. АНАЛИЗ ЦЕЛЕВОЙ ПЕРЕМЕННОЙ (poutcome)")
print("═"*50)
print("Распределение значений:")
print(df['poutcome'].value_counts(normalize=True)*100)


plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='poutcome', order=df['poutcome'].value_counts().index)
plt.title('Распределение результатов предыдущей кампании (poutcome)')
plt.show()

num_cols = df.select_dtypes(include=['int64', 'float64']).columns
print("\n" + "═"*50)
print("2. СВЯЗЬ POUTCOME С ЧИСЛОВЫМИ ПЕРЕМЕННЫМИ")
print("═"*50)

for col in num_cols:
    plt.figure(figsize=(10, 5))
    sns.boxplot(data=df, x='poutcome', y=col)
    plt.title(f'Распределение {col} по результатам кампании')
    plt.show()

cat_cols = df.select_dtypes(include=['object']).drop(columns=['y']).columns
print("\n" + "═"*50)
print("3. СВЯЗЬ POUTCOME С КАТЕГОРИАЛЬНЫМИ ПЕРЕМЕННЫМИ")
print("═"*50)

for col in cat_cols:
    if col != 'poutcome':
        plt.figure(figsize=(12, 6))
        sns.countplot(data=df, x=col, hue='poutcome',
                     order=df[col].value_counts().iloc[:10].index)
        plt.title(f'Распределение {col} по результатам кампании')
        plt.xticks(rotation=45)
        plt.legend(title='poutcome')
        plt.show()

# Статистический анализ
print("\n" + "═"*50)
print("4. СТАТИСТИЧЕСКИЙ АНАЛИЗ СВЯЗЕЙ")
print("═"*50)

# Тест ANOVA для числовых переменных
print("\nANOVA тесты для числовых переменных:")
for col in num_cols:
    groups = [df[df['poutcome']==cat][col] for cat in df['poutcome'].unique()]
    f_stat, p_val = stats.f_oneway(*groups)
    print(f"{col}: F={f_stat:.2f}, p={p_val:.4f}")

# Хи-квадрат для категориальных переменных
print("\nХи-квадрат тесты для категориальных переменных:")
for col in cat_cols:
    if col != 'poutcome':
        contingency_table = pd.crosstab(df[col], df['poutcome'])
        chi2, p, dof, expected = chi2_contingency(contingency_table)
        print(f"{col}: χ²={chi2:.2f}, p={p:.4f}")

# 5. Анализ временных параметров
print("\n" + "═"*50)
print("5. ВРЕМЕННОЙ АНАЛИЗ")
print("═"*50)

# Распределение по месяцам
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='month', hue='poutcome',
             order=['mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'])
plt.title('Результаты кампании по месяцам')
plt.show()

# Распределение по дням недели
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='day_of_week', hue='poutcome',
             order=['mon', 'tue', 'wed', 'thu', 'fri'])
plt.title('Результаты кампании по дням недели')
plt.show()

# Анализ успешных случаев (success)
print("\n" + "═"*50)
print("6. АНАЛИЗ УСПЕШНЫХ КЕЙСОВ (success)")
print("═"*50)
success_data = df[df['poutcome'] == 'success']
print(f"Количество успешных случаев: {len(success_data)} ({len(success_data)/len(df)*100:.2f}%)")

# Характеристики успешных случаев
print("\nСредние значения для успешных случаев:")
print(success_data[num_cols].mean())

# Профиль успешного клиента
print("\nЧастые характеристики успешных клиентов:")
for col in ['job', 'marital', 'education', 'contact']:
    print(f"\n{col}:")
    print(success_data[col].value_counts(normalize=True).head(3)*100)
# Out:
# ══════════════════════════════════════════════════
# 1. АНАЛИЗ ЦЕЛЕВОЙ ПЕРЕМЕННОЙ (poutcome)
# ══════════════════════════════════════════════════
# Распределение значений:
# poutcome
# nonexistent    86.343110
# failure        10.323395
# success         3.333495
# Name: proportion, dtype: float64
# ══════════════════════════════════════════════════
# 2. СВЯЗЬ POUTCOME С ЧИСЛОВЫМИ ПЕРЕМЕННЫМИ
# ══════════════════════════════════════════════════
# ══════════════════════════════════════════════════
# 3. СВЯЗЬ POUTCOME С КАТЕГОРИАЛЬНЫМИ ПЕРЕМЕННЫМИ
# ══════════════════════════════════════════════════
# ══════════════════════════════════════════════════
# 4. СТАТИСТИЧЕСКИЙ АНАЛИЗ СВЯЗЕЙ
# ══════════════════════════════════════════════════
#
# ANOVA тесты для числовых переменных:
# age: F=26.17, p=0.0000
# duration: F=43.84, p=0.0000
# campaign: F=162.07, p=0.0000
# pdays: F=200141.74, p=0.0000
# previous: F=76902.71, p=0.0000
# emp.var.rate: F=5976.38, p=0.0000
# cons.price.idx: F=2235.35, p=0.0000
# cons.conf.idx: F=681.19, p=0.0000
# euribor3m: F=6579.02, p=0.0000
# nr.employed: F=7296.83, p=0.0000
#
# Хи-квадрат тесты для категориальных переменных:
# job: χ²=838.48, p=0.0000
# marital: χ²=116.53, p=0.0000
# education: χ²=161.26, p=0.0000
# default: χ²=487.68, p=0.0000
# housing: χ²=27.69, p=0.0000
# loan: χ²=1.60, p=0.8092
# contact: χ²=2422.43, p=0.0000
# month: χ²=4858.01, p=0.0000
# day_of_week: χ²=25.51, p=0.0013
#
# ══════════════════════════════════════════════════
# 5. ВРЕМЕННОЙ АНАЛИЗ
# ══════════════════════════════════════════════════
# ══════════════════════════════════════════════════
# 6. АНАЛИЗ УСПЕШНЫХ КЕЙСОВ (success)
# ══════════════════════════════════════════════════
# Количество успешных случаев: 1373 (3.33%)
#
# Средние значения для успешных случаев:
# age                 42.023307
# duration           320.941733
# campaign             1.808449
# pdays                5.587764
# previous             1.569556
# emp.var.rate        -2.091260
# cons.price.idx      93.334355
# cons.conf.idx      -38.388565
# euribor3m            0.996563
# nr.employed       5030.622433
# dtype: float64
#
# Частые характеристики успешных клиентов:
#
# job:
# job
# admin.        31.172615
# technician    15.367808
# retired       11.507647
# Name: proportion, dtype: float64
#
# marital:
# marital
# married     52.658412
# single      37.581937
# divorced     9.395484
# Name: proportion, dtype: float64
#
# education:
# education
# university.degree      38.820102
# high.school            21.412964
# professional.course    13.328478
# Name: proportion, dtype: float64
#
# contact:
# contact
# cellular     92.498179
# telephone     7.501821
# Name: proportion, dtype: float64

# %%
# Пример замены значений в DataFrame
df['education'] = df['education'].replace({
    'university.degree': 'higher',
    'professional.course': 'higher',
    'high.school': 'secondary',
    'basic.9y': 'secondary',
    'basic.6y': 'secondary',  # или 'low' в альтернативном варианте
    'basic.4y': 'low',
    'illiterate': 'low',
    'unknown': 'low'
})

# %%
df['education'].value_counts() #need optimization
# Out:
# education
# secondary    17852
# higher       17411
# low           5925
# Name: count, dtype: int64

# %%
# Define the job grouping mapping
job_groups = {
    'office_workers': ['admin.', 'management'],
    'manual_labor': ['blue-collar', 'housemaid'],
    'tech_related': ['technician', 'self-employed', 'entrepreneur'],
    'service_sector': ['services'],
    'inactive': ['retired', 'unemployed', 'student'],
    'other': ['unknown']
}

# Reverse the mapping to create a dictionary for replacement
group_mapping = {}
for group, jobs in job_groups.items():
    for job in jobs:
        group_mapping[job] = group

# Apply the mapping to create a new column
df['job'] = df['job'].map(group_mapping)
df['job'].value_counts()
# Out:
# job
# office_workers    13346
# manual_labor      10314
# tech_related       9620
# service_sector     3969
# inactive           3609
# other               330
# Name: count, dtype: int64

# %%
df.drop(df[df['default'] == 'unknown'].index, inplace=True)
df['default'] = df['default'].map({'no': 0.0, 'yes': 1.0})

# %%
# Step 1: Drop unknown marital status rows
df = df[df['marital'] != 'unknown'].copy()

# Step 2: Create optimized column
df['marital'] = df['marital'].map({
    'single': 'single',
    'married': 'in_relationship',
    'divorced': 'single'  # assuming divorced people were previously in relationships
})

# %%
df['marital'].value_counts()
# Out:
# marital
# in_relationship    18658
# single             13864
# Name: count, dtype: int64

# %% [raw]
# Possible Hypothesis
#
# H0: There is no relationship between subscribing and beign in default.
# H1: There is a relationship between subscribing and beign in default.

# %%
df.drop(df[df['loan'] == 'unknown'].index, inplace=True)

# %%
df['housing'] = df['housing'].map({'no': 0.0, 'yes': 1.0})
df
# Out:
#        age             job          marital  education  default  housing loan  \
# 0       56    manual_labor  in_relationship        low      0.0      0.0   no
# 2       37  service_sector  in_relationship  secondary      0.0      1.0   no
# 3       40  office_workers  in_relationship  secondary      0.0      0.0   no
# 4       56  service_sector  in_relationship  secondary      0.0      0.0  yes
# 6       59  office_workers  in_relationship     higher      0.0      0.0   no
# ...    ...             ...              ...        ...      ...      ...  ...
# 41183   73        inactive  in_relationship     higher      0.0      1.0   no
# 41184   46    manual_labor  in_relationship     higher      0.0      0.0   no
# 41185   56        inactive  in_relationship     higher      0.0      1.0   no
# 41186   44    tech_related  in_relationship     higher      0.0      0.0   no
# 41187   74        inactive  in_relationship     higher      0.0      1.0   no
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# 0      telephone   may         mon       261         1    999         0
# 2      telephone   may         mon       226         1    999         0
# 3      telephone   may         mon       151         1    999         0
# 4      telephone   may         mon       307         1    999         0
# 6      telephone   may         mon       139         1    999         0
# ...          ...   ...         ...       ...       ...    ...       ...
# 41183   cellular   nov         fri       334         1    999         0
# 41184   cellular   nov         fri       383         1    999         0
# 41185   cellular   nov         fri       189         2    999         0
# 41186   cellular   nov         fri       442         1    999         0
# 41187   cellular   nov         fri       239         3    999         1
#
#           poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent           1.1          93.994          -36.4      4.857
# 2      nonexistent           1.1          93.994          -36.4      4.857
# 3      nonexistent           1.1          93.994          -36.4      4.857
# 4      nonexistent           1.1          93.994          -36.4      4.857
# 6      nonexistent           1.1          93.994          -36.4      4.857
# ...            ...           ...             ...            ...        ...
# 41183  nonexistent          -1.1          94.767          -50.8      1.028
# 41184  nonexistent          -1.1          94.767          -50.8      1.028
# 41185  nonexistent          -1.1          94.767          -50.8      1.028
# 41186  nonexistent          -1.1          94.767          -50.8      1.028
# 41187      failure          -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# 6           5191.0   no
# ...            ...  ...
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [31760 rows x 21 columns]

# %%
df['campaign'] = df['campaign'].apply(lambda x: 0 if x == 1 else 1)

# %%
df['campaign'].value_counts()
# Out:
# campaign
# 0    2498
# 1    2408
# Name: count, dtype: int64

# %%
df.drop(df[df['poutcome'] == 'nonexistent'].index, inplace=True)

# %%
#Create dummy-variables 1
Edu_dummy=pd.get_dummies(df['education'], prefix='', prefix_sep='_')
Edu_dummy.head()
# illiterate = ref.group.
# Out:
#        _higher   _low  _secondary
# 24013    False   True       False
# 24019    False  False        True
# 24076     True  False       False
# 24102    False  False        True
# 24108     True  False       False

# %%
#Create dummy-variables 2
Work_dummy=pd.get_dummies(df['job'], prefix='', prefix_sep='_')
Work_dummy.head()
# Out:
#        _inactive  _manual_labor  _office_workers  _other  _service_sector  \
# 24013      False           True            False   False            False
# 24019      False          False            False   False             True
# 24076      False          False             True   False            False
# 24102      False          False             True   False            False
# 24108      False          False             True   False            False
#
#        _tech_related
# 24013          False
# 24019          False
# 24076          False
# 24102          False
# 24108          False

# %%
df['poutcome'] = df['poutcome'].map({'failure': 0.0, 'success': 1.0})

# %%
df['marital'] = df['marital'].map({'single': 0.0, 'in_relationship': 1.0})

# %%
df['loan'] = df['loan'].map({'no': 0.0, 'yes': 1.0})

# %%
df
# Out:
#        age             job  marital  education  default  housing  loan  \
# 24013   38    manual_labor      0.0        low      0.0      1.0   0.0
# 24019   40  service_sector      1.0  secondary      0.0      1.0   0.0
# 24076   36  office_workers      1.0     higher      0.0      1.0   0.0
# 24102   36  office_workers      1.0  secondary      0.0      1.0   0.0
# 24108   37  office_workers      1.0     higher      0.0      1.0   0.0
# ...    ...             ...      ...        ...      ...      ...   ...
# 41174   62        inactive      1.0     higher      0.0      1.0   0.0
# 41175   34        inactive      0.0        low      0.0      1.0   0.0
# 41178   62        inactive      1.0     higher      0.0      0.0   0.0
# 41182   29        inactive      0.0        low      0.0      1.0   0.0
# 41187   74        inactive      1.0     higher      0.0      1.0   0.0
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# 24013  telephone   oct         tue        39         1    999         1
# 24019  telephone   oct         tue       144         1    999         1
# 24076  telephone   nov         wed       449         1    999         1
# 24102  telephone   nov         wed       114         1    999         1
# 24108  telephone   nov         wed       119         1      6         1
# ...          ...   ...         ...       ...       ...    ...       ...
# 41174   cellular   nov         thu       208         1      1         6
# 41175   cellular   nov         thu       180         1    999         2
# 41178   cellular   nov         thu       483         2      6         3
# 41182   cellular   nov         fri       112         1      9         1
# 41187   cellular   nov         fri       239         3    999         1
#
#        poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 24013       0.0          -0.1          93.798          -40.4      4.968
# 24019       0.0          -0.1          93.798          -40.4      4.968
# 24076       0.0          -0.1          93.200          -42.0      4.663
# 24102       0.0          -0.1          93.200          -42.0      4.286
# 24108       1.0          -0.1          93.200          -42.0      4.286
# ...         ...           ...             ...            ...        ...
# 41174       1.0          -1.1          94.767          -50.8      1.031
# 41175       0.0          -1.1          94.767          -50.8      1.031
# 41178       1.0          -1.1          94.767          -50.8      1.031
# 41182       1.0          -1.1          94.767          -50.8      1.028
# 41187       0.0          -1.1          94.767          -50.8      1.028
#
#        nr.employed    y  _inactive  _manual_labor  _office_workers  _other  \
# 24013       5195.8   no      False           True            False   False
# 24019       5195.8  yes      False          False            False   False
# 24076       5195.8   no      False          False             True   False
# 24102       5195.8  yes      False          False             True   False
# 24108       5195.8   no      False          False             True   False
# ...            ...  ...        ...            ...              ...     ...
# 41174       4963.6  yes       True          False            False   False
# 41175       4963.6   no       True          False            False   False
# 41178       4963.6  yes       True          False            False   False
# 41182       4963.6   no       True          False            False   False
# 41187       4963.6   no       True          False            False   False
#
#        _service_sector  _tech_related  _higher   _low  _secondary
# 24013            False          False    False   True       False
# 24019             True          False    False  False        True
# 24076            False          False     True  False       False
# 24102            False          False    False  False        True
# 24108            False          False     True  False       False
# ...                ...            ...      ...    ...         ...
# 41174            False          False     True  False       False
# 41175            False          False    False   True       False
# 41178            False          False     True  False       False
# 41182            False          False    False   True       False
# 41187            False          False     True  False       False
#
# [4906 rows x 30 columns]

# %%
df = pd.concat([df, Work_dummy, Edu_dummy], axis=1)

# %%
df_model = df.dropna(subset=['age','marital','housing','loan'
                              ,'_manual_labor',	'_office_workers',	'_other',	'_service_sector',	'_tech_related',
                                        '_higher',	'_secondary','poutcome', 'duration',	'campaign'])
df_model.shape



# I am not going to add '_admin.' and '_blue-collar' jobs in model because they cause multicollinearity problem at the end!!!
# Out:
# (4906, 30)

# %%
x_mult = df_model[['age','marital','housing','loan'
                              ,'_manual_labor',	'_office_workers',	'_other',	'_service_sector',	'_tech_related',
                                        '_higher',	'_secondary', 'duration',	'campaign']]
y = df_model['poutcome']
x_mult_constant = sm.add_constant(x_mult)

# %%
model = sm.Logit(y.astype(float), x_mult_constant.astype(float)).fit()
print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.542802
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               poutcome   No. Observations:                 4906
# Model:                          Logit   Df Residuals:                     4892
# Method:                           MLE   Df Model:                           13
# Date:                Sat, 07 Jun 2025   Pseudo R-squ.:                 0.05505
# Time:                        11:54:22   Log-Likelihood:                -2663.0
# converged:                       True   LL-Null:                       -2818.1
# Covariance Type:            nonrobust   LLR p-value:                 1.687e-58
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              -0.5967      0.190     -3.141      0.002      -0.969      -0.224
# age                 0.0035      0.003      1.223      0.221      -0.002       0.009
# marital            -0.0627      0.074     -0.852      0.394      -0.207       0.082
# housing            -0.0120      0.068     -0.177      0.860      -0.145       0.121
# loan               -0.0517      0.093     -0.555      0.579      -0.234       0.131
# _manual_labor      -1.2647      0.126    -10.041      0.000      -1.512      -1.018
# _office_workers    -0.7159      0.102     -7.031      0.000      -0.915      -0.516
# _other              0.4952      0.380      1.303      0.193      -0.250       1.240
# _service_sector    -1.2629      0.162     -7.784      0.000      -1.581      -0.945
# _tech_related      -0.9848      0.115     -8.589      0.000      -1.210      -0.760
# _higher             0.1204      0.116      1.034      0.301      -0.108       0.349
# _secondary         -0.3020      0.115     -2.619      0.009      -0.528      -0.076
# duration            0.0011      0.000      8.512      0.000       0.001       0.001
# campaign           -0.0736      0.067     -1.091      0.275      -0.206       0.059
# ===================================================================================

# %%
model = sm.Logit(y.astype(float), x_mult_constant.astype(float)).fit()
print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.542802
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               poutcome   No. Observations:                 4906
# Model:                          Logit   Df Residuals:                     4892
# Method:                           MLE   Df Model:                           13
# Date:                Sat, 07 Jun 2025   Pseudo R-squ.:                 0.05505
# Time:                        11:54:26   Log-Likelihood:                -2663.0
# converged:                       True   LL-Null:                       -2818.1
# Covariance Type:            nonrobust   LLR p-value:                 1.687e-58
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              -0.5967      0.190     -3.141      0.002      -0.969      -0.224
# age                 0.0035      0.003      1.223      0.221      -0.002       0.009
# marital            -0.0627      0.074     -0.852      0.394      -0.207       0.082
# housing            -0.0120      0.068     -0.177      0.860      -0.145       0.121
# loan               -0.0517      0.093     -0.555      0.579      -0.234       0.131
# _manual_labor      -1.2647      0.126    -10.041      0.000      -1.512      -1.018
# _office_workers    -0.7159      0.102     -7.031      0.000      -0.915      -0.516
# _other              0.4952      0.380      1.303      0.193      -0.250       1.240
# _service_sector    -1.2629      0.162     -7.784      0.000      -1.581      -0.945
# _tech_related      -0.9848      0.115     -8.589      0.000      -1.210      -0.760
# _higher             0.1204      0.116      1.034      0.301      -0.108       0.349
# _secondary         -0.3020      0.115     -2.619      0.009      -0.528      -0.076
# duration            0.0011      0.000      8.512      0.000       0.001       0.001
# campaign           -0.0736      0.067     -1.091      0.275      -0.206       0.059
# ===================================================================================

# %%
coefs = pd.DataFrame()
coefs['Coefs'] = model.params[1:]
coefs['Features'] = model.params.index[1:]
coefs.set_index('Features', inplace=True)
print('Intercept = ', model.params[0])
coefs
#regression coefficients
# Out:
# Intercept =  -0.5966618821024089
# <ipython-input-178-82811356d3fe>:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print('Intercept = ', model.params[0])
#                     Coefs
# Features
# age              0.003522
# marital         -0.062738
# housing         -0.012009
# loan            -0.051724
# _manual_labor   -1.264712
# _office_workers -0.715902
# _other           0.495192
# _service_sector -1.262892
# _tech_related   -0.984845
# _higher          0.120407
# _secondary      -0.302003
# duration         0.001128
# campaign        -0.073576

# %%
coefs['OddsRatio'] = np.exp(coefs.Coefs)
coefs
#regression coefficient and odds ratio
# Out:
#                     Coefs  OddsRatio
# Features
# age              0.003522   1.003528
# marital         -0.062738   0.939190
# housing         -0.012009   0.988062
# loan            -0.051724   0.949591
# _manual_labor   -1.264712   0.282321
# _office_workers -0.715902   0.488751
# _other           0.495192   1.640813
# _service_sector -1.262892   0.282835
# _tech_related   -0.984845   0.373497
# _higher          0.120407   1.127955
# _secondary      -0.302003   0.739336
# duration         0.001128   1.001129
# campaign        -0.073576   0.929066

# %% [raw]
# Comments:
#
# 1)Some other attributes. Significant. As p-value<0.05. If we consider 'Other attributes' which consist of number of contacts performed before and during this campaign, passed days altogether, we can assume that with the increase of one unit, the odds of subscription will increase by 46%.
# 2) Socio-economic factors. Significant. As p-value<0.05. Talking about employment rate, consumer price, consumer confidence index and so on...which altogether formulate "Socio-economic attributes", if the latter increses by one unit, the odds to subscribe will increase by 78%.
# 3) Age. Whenever a person becomes 1 year older, the odds  to subscribe will increase by 0,1%. Actually, it is not very important because p-value=0.518>0.05.
# 4) If a person is concacted via telephone, but not cellular, the odds to impose the service are decreased by 20%. Significant. As p-value<0.05
# 5) If a person is for sure free from default obliigations, the odds to subscribe will increase by 58%. Significant. As p-value<0.05
# 6) If we consider basic education, the odds to be imposed the subscription will decrease by 33% as opposed to illiterate people. Significant. As p-value<0.05
# 7) If we consider only high-school education, the odds to be imposed the subscription will decrease by 20% as opposed to illiterate people. Significant. As p-value<0.05
# 8) If we consider course education, the odds to be imposed the subscription will decrease by 15% as opposed to illiterate people. Significant. As p-value<0.05
# 9) If we consider entrepreneurs, the odds to be imposed the subscription will decrease by 19% as opposed to students. Significant. As p-value<0.05
# 10) If we consider households, the odds to be imposed the subscription will increase by 16% as opposed to students. Not significant. As p-value>0.05
# 11) If we consider managers, the odds to be imposed the subscription will decrease by 15% as opposed to students. Significant. As p-value<0.05
# 12) For the retired people the odds for the subscriptions are 2 times higher than for students. Not significant. As p-value>0.05
# 13) For self-employed, the odds for the subscriptions are 7 % lower than for students. Not significant. As p-value>0.05
# 14) If we consider service staff, the odds for the subscriptions are 20 % lower than for students. Significant. As p-value below 0.05
# 15) For the techicians, the odds for the subscriptions are 3% lower than for students. Not significant. As p-value>0.05
# 16) If we consider unemployed people, the odds for their subscription are 25 % higher than for students. Significant. As p-value below 0.05

# %%
def yes_no(p_value, level = 0.05):
    if abs(p_value) < level:
        return 'significant'
    else:
        return 'non-significant'
pvals = pd.DataFrame()
pvals['p_values'] = model.pvalues[1:]
pvals['5% level']= pvals['p_values'].apply(yes_no)
pvals['p_values'] = pvals['p_values'].map('{:.3f}'.format)
pvals['Features'] = model.params.index[1:]
pvals.set_index('Features',inplace=True)
pvals


#I want to generate the table in a more convienent way to see what is significant and not.
# Out:
#                 p_values         5% level
# Features
# age                0.221  non-significant
# marital            0.394  non-significant
# housing            0.860  non-significant
# loan               0.579  non-significant
# _manual_labor      0.000      significant
# _office_workers    0.000      significant
# _other             0.193  non-significant
# _service_sector    0.000      significant
# _tech_related      0.000      significant
# _higher            0.301  non-significant
# _secondary         0.009      significant
# duration           0.000      significant
# campaign           0.275  non-significant

# %%
pvals['10% level'] = model.pvalues[1:].apply(lambda x: yes_no(x, level=0.1))
pvals

#I want to generate the table in a more convienent way to see what is significant and not.
#But with the increased level of importance.
# Out:
#                 p_values         5% level        10% level
# Features
# age                0.221  non-significant  non-significant
# marital            0.394  non-significant  non-significant
# housing            0.860  non-significant  non-significant
# loan               0.579  non-significant  non-significant
# _manual_labor      0.000      significant      significant
# _office_workers    0.000      significant      significant
# _other             0.193  non-significant  non-significant
# _service_sector    0.000      significant      significant
# _tech_related      0.000      significant      significant
# _higher            0.301  non-significant  non-significant
# _secondary         0.009      significant      significant
# duration           0.000      significant      significant
# campaign           0.275  non-significant  non-significant

# %% [raw]
# H0:'Other attributes' do not bring a significant contribution to the positive outcome in the final model.
# H1: 'Other attributes' bring a significant contribution to the positive outcome in the final model. - Accepted
#
# H0:'Socio-economic factors' do not bring a significant contribution to the positive outcome in the final model
# H1: 'Socio-economic factors' bring a significant contribution to the positive outcome in the final model.  - Accepted
#
# H0:'age' does not bring a significant contribution to the positive outcome in the final model  - Accepted
# H1: 'age' brings a significant contribution to the positive outcome in the final model
#
# H0: Being in 'default' does not bring a significant contribution to the positive outcome in the final model
# H1: Being in'default' matters a contribution to the positive outcome in the final model  - Accepted
#
# H0: 'education' does not influence the positive outcome in the final model
# H1: 'education' does influence the positive outcome in the final model  - Accepted
#
# H0: There is no impact between being called via cellular or modile phone on the positive outcome in the final model
# H1: There is an impact between being called either by cellular or modile phone on the positive outcome in the final model  - Accepted
#
# H0: 'job' does not bring a significant contribution to the positive outcome in the final model -not rejected
# H1: 'job' does bring a significant contribution to the positive outcome in the final model  - not rejected
# ( not for technicians, households and self-employed.)

# %% [markdown]
# I want to characterize the model.

# %%
print('R^2 = {:f}'.format(model.prsquared))
print('Model significance = {:f}'.format(model.llr_pvalue))
# significant as <0.05 but it explains only 15% of variation.
# Out:
# R^2 = 0.055052
# Model significance = 0.000000

# %%
f'Statistically significant model parameters: {model.pvalues[model.pvalues < 0.05].index.values}'
# Out:
# "Statistically significant model parameters: ['const' '_manual_labor' '_office_workers' '_service_sector'\n '_tech_related' '_secondary' 'duration']"

# %%
f'Statistically nonsignificant model parameters: {model.pvalues[model.pvalues > 0.05].index.values}'
# Out:
# "Statistically nonsignificant model parameters: ['age' 'marital' 'housing' 'loan' '_other' '_higher' 'campaign']"

# %%
l = []
for (param, index) in zip(model.params[1:], model.params.index[1:]):
    l.append('{:.2f}*{}'.format(param, index))

print('logit(p) = {:2f} + {}'.format(model.params[0], ' + '.join(l)))


# I want to specify the regression equation
# Out:
# logit(p) = -0.596662 + 0.00*age + -0.06*marital + -0.01*housing + -0.05*loan + -1.26*_manual_labor + -0.72*_office_workers + 0.50*_other + -1.26*_service_sector + -0.98*_tech_related + 0.12*_higher + -0.30*_secondary + 0.00*duration + -0.07*campaign
# <ipython-input-185-cbb8b0eba4b6>:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print('logit(p) = {:2f} + {}'.format(model.params[0], ' + '.join(l)))

# %%
cm = model.pred_table()
print('TP: {} | FN: {}\n-------------------\nFP: {}  | TN: {}'.format(cm[0,0], cm[0,1], cm[1,0], cm[1,1]))
# Out:
# TP: 3531.0 | FN: 93.0
# -------------------
# FP: 1197.0  | TN: 85.0

# %%
accuracy = (cm[0,0] + cm[1,1]) / sum(sum(cm))
print('Accuracy: {}'.format(accuracy))
# Out:
# Accuracy: 0.7370566653077864

# %% [markdown]
# The accuracy is 89% this is not very high but also nut very low. We are supposed to have predicted 89% of cases.

# %%
df_model['poutcome'] = [int(i) for i in df_model['poutcome']] #I want to align all Y-s otherwise I cannot make a graph.
fpr, tpr, _ = roc_curve(df_model['poutcome'], model.predict())
roc_auc = auc(fpr, tpr)

# %%
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# S=76 square units out of 100.

# %%
#Diagnostics - I want to consider the residuals

p = stats.kstest(model.resid_generalized, 'norm', args=(model.resid_generalized.mean(), model.resid_generalized.std())).pvalue
print('P-value: {:.3f}'.format(p))
# Out:
# P-value: 0.000

# %%
# P-value <0.05 inducates a different from normal distribution.

sns.distplot(model.resid_generalized, fit=stats.norm)
# Out:
# <ipython-input-191-35515334cbfe>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(model.resid_generalized, fit=stats.norm)
# <Axes: ylabel='Density'>

# %%
#Diagnostics - I want to consider the multicollinearity

vifs = np.array([vif(model.model.exog, i) for i in range(model.model.exog.shape[1])])

# %%
vif_df = pd.DataFrame()
vif_df['VIF'] = vifs[1:]
vif_df['Features'] = model.params.index[1:]
vif_df.sort_values(by=['VIF'])
# Out:
#          VIF         Features
# 3   1.002829             loan
# 2   1.003335          housing
# 11  1.004338         duration
# 12  1.005164         campaign
# 6   1.036998           _other
# 1   1.178514          marital
# 0   1.310187              age
# 7   1.611548  _service_sector
# 4   1.958769    _manual_labor
# 8   2.248323    _tech_related
# 5   2.559048  _office_workers
# 10  2.906153       _secondary
# 9   3.217366          _higher

# %% [markdown]
# I want to ensure that there is no multicollinearity problem.

# %% [markdown]
# As all VIFs do not exceed 10, indeed there is no multicollinearity problem.

# %%
# I want to save the probability for each case in the table.

df_model['probability'] = model.predict()
df_model
# Out:
#        age             job  marital  education  default  housing  loan  \
# 24013   38    manual_labor      0.0        low      0.0      1.0   0.0
# 24019   40  service_sector      1.0  secondary      0.0      1.0   0.0
# 24076   36  office_workers      1.0     higher      0.0      1.0   0.0
# 24102   36  office_workers      1.0  secondary      0.0      1.0   0.0
# 24108   37  office_workers      1.0     higher      0.0      1.0   0.0
# ...    ...             ...      ...        ...      ...      ...   ...
# 41174   62        inactive      1.0     higher      0.0      1.0   0.0
# 41175   34        inactive      0.0        low      0.0      1.0   0.0
# 41178   62        inactive      1.0     higher      0.0      0.0   0.0
# 41182   29        inactive      0.0        low      0.0      1.0   0.0
# 41187   74        inactive      1.0     higher      0.0      1.0   0.0
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# 24013  telephone   oct         tue        39         0    999         1
# 24019  telephone   oct         tue       144         0    999         1
# 24076  telephone   nov         wed       449         0    999         1
# 24102  telephone   nov         wed       114         0    999         1
# 24108  telephone   nov         wed       119         0      6         1
# ...          ...   ...         ...       ...       ...    ...       ...
# 41174   cellular   nov         thu       208         0      1         6
# 41175   cellular   nov         thu       180         0    999         2
# 41178   cellular   nov         thu       483         1      6         3
# 41182   cellular   nov         fri       112         0      9         1
# 41187   cellular   nov         fri       239         1    999         1
#
#        poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 24013         0          -0.1          93.798          -40.4      4.968
# 24019         0          -0.1          93.798          -40.4      4.968
# 24076         0          -0.1          93.200          -42.0      4.663
# 24102         0          -0.1          93.200          -42.0      4.286
# 24108         1          -0.1          93.200          -42.0      4.286
# ...         ...           ...             ...            ...        ...
# 41174         1          -1.1          94.767          -50.8      1.031
# 41175         0          -1.1          94.767          -50.8      1.031
# 41178         1          -1.1          94.767          -50.8      1.031
# 41182         1          -1.1          94.767          -50.8      1.028
# 41187         0          -1.1          94.767          -50.8      1.028
#
#        nr.employed    y  _inactive  _manual_labor  _office_workers  _other  \
# 24013       5195.8   no      False           True            False   False
# 24019       5195.8  yes      False          False            False   False
# 24076       5195.8   no      False          False             True   False
# 24102       5195.8  yes      False          False             True   False
# 24108       5195.8   no      False          False             True   False
# ...            ...  ...        ...            ...              ...     ...
# 41174       4963.6  yes       True          False            False   False
# 41175       4963.6   no       True          False            False   False
# 41178       4963.6  yes       True          False            False   False
# 41182       4963.6   no       True          False            False   False
# 41187       4963.6   no       True          False            False   False
#
#        _service_sector  _tech_related  _higher   _low  _secondary  probability
# 24013            False          False    False   True       False     0.155045
# 24019             True          False    False  False        True     0.126419
# 24076            False          False     True  False       False     0.346690
# 24102            False          False    False  False        True     0.192486
# 24108            False          False     True  False       False     0.268476
# ...                ...            ...      ...    ...         ...          ...
# 41174            False          False     True  False       False     0.475513
# 41175            False          False    False   True       False     0.429012
# 41178            False          False     True  False       False     0.537586
# 41182            False          False    False   True       False     0.406078
# 41187            False          False     True  False       False     0.476424
#
# [4906 rows x 31 columns]

# %% [raw]
# The model is weak itself (Pseudo R covers only 14,9% of variation). It's very difficult to establish any significant relationships, especially when it comes to human behaviour.
#
# However, in those 14,9% I managed to detect the following:
#
# -If we consider 'Other attributes' which mainly consist of the amount of time with the increase of which, we will  increase odds of subscription by 46%. Time matters indeed.
#
# -Talking about employment rate, consumer price, consumer confidence index and so on...which altogether formulate "Socio-economic attributes", if the latter increases by one unit, the odds to subscribe will increase by 78%.
#
#
#
# -If a person is contacted via telephone, but not cellular, the odds to impose the service are decreased by 20%.
# Maybe because cellulars are out of the fashion and only elderly people use cellulars who are presumably ealiy influenced?
#
# -If a person is for sure free from default obliigations, the odds to subscribe will increase by 58%. That sounds reasonable because in this case whenever a person is free from obligations, he has more opportunities in terms of...everything.
#
# - If we consider people with basic education or high-school education, or course education, or whatever education, the odds to be imposed the subscription service are decreased by at least 15% as opposed to those people who don't have any education at all. That's not so strange. Probably, educated people are smart enough not to fall for that or they just have enough computer literacy...
#
# - As for the workers such as entrepreneurs, managers and service staff, the odds to be imposed the subscription are decreased  as opposed to students. Maybe at the beginnig of their career students are more outgoing and looking for different opportunities.
#
# - If we consider unemployed people, the odds for their subscription are 25 % higher than for students. Probably, because the unemployed are looking for a job using different sources...
#
# Other parameters are not signigicant...
